# %%
import tweepy

# %%
auth = tweepy.OAuthHandler("p4KtAyA62KzBWYQpcE266Qz15",
                          "H0NJF4yqFg9QeFd9okrlf7JVHvtnapoxrdzuz535CmvCvszbuC")

# %%
auth.set_access_token("3013571240-aK5vnnjmP9OVq4GZlJAlx05zcbKml3ZciR4GwEA",
                      "jRgzCRsHtXV1zxQJQpg7cHGL7P55B62qOjcK6QRfdcZ6M")

# %%
#override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
#         raise ValueError()
        if status.lang == 'en' and not status.text.startswith("RT"):
            tweets[status.id_str] = status.text
            print(status.text)
#             import pdb; pdb.
            
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False
#         import pdb; pdb.set_trace()

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = auth, listener=myStreamListener)

# %%
tweets = {}
myStream.filter(track=['life'])
# Out:
# John 5:24 KJV: Verily, verily, I say unto you, He that heareth my word, and believeth on him that sent me, hath eve… https://t.co/1cGcySSrCR
# I thought he was gonna propose, not try and stick it in me arse
# the love of my life? yes
# Stan twt                      irl https://t.co/2WIuOpA46r
# Great watch with Will and @realmartymar
# It was YOU -
# Who cleaned the mirror Of my life
# It is YOU
# Who bit the apple of LOVE
# Along with me
#
# https://t.co/GfnG01E06E
#
# .
# Truly, truly, I say to you, whoever hears my word and believes him who sent me has eternal life. He…… https://t.co/R1DzJwb004
# And through it all he offers me protection
# A lot of love and affection
# Whether I'm right or wrong
# And down the wate… https://t.co/DoUpB5Tnac
# Saturday night# twisted Cricus🎪# circo$ domperingon🍾 Pierre de jouet champagne 🍾courvoiser# madanes# dancers# fire🔥… https://t.co/gXpC8nKqln
# ...

# %%
len(tweets)
# Out:
# 206

# %%
import json

with open("tweets.json", 'w') as f:
    json.dump(tweets, f)
